# %%
# data minimum aur maximum values k ander reduce hta hy 
# hmy data ka range 0-1 me milta , also known as min-max scaling.

# %% [markdown]
# Xnew = (Xi - min(X))/ (max(X) - min(X))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("loan.csv")
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
from sklearn.preprocessing import MinMaxScaler
ms  =  MinMaxScaler()

# %%
ms.fit(df[["CoapplicantIncome"]])
# Out:
# MinMaxScaler()

# %%
df["CoapplicantIncome_ms"]= ms.transform(df[["CoapplicantIncome"]])

# %%
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status  CoapplicantIncome_ms
# 0             1.0         Urban           Y              0.000000
# 1             1.0         Rural           N              0.036192
# 2             1.0         Urban           Y              0.000000

# %%
plt.subplot(1,2,1)
sns.distplot(df["CoapplicantIncome"])
plt.subplot(1,2,2)
sns.distplot(df["CoapplicantIncome_ms"])
plt.show()
# Out:
# Could not connect to 127.0.0.1: 62143
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2024.1.1\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_comm.py", line 465, in start_client
#     s.connect((host, port))
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2024.1.1\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_utils.py", line 81, in attach_to_debugger
#     debugger.connect(pydev_localhost.get_localhost(), debugger_port)
#   File "C:\Program Files\JetBrains\PyCharm 2024.1.1\plugins\python\helpers\pydev\pydevd.py", line 671, in connect
#     s = start_client(host, port)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\JetBrains\PyCharm 2024.1.1\plugins\python\helpers\pydev\_pydevd_bundle\pydevd_comm.py", line 465, in start_client
#     s.connect((host, port))
# ...

# %% [markdown]
# ###### data reduced between 0 - 1
